# %%
import deeplabcut as dlc
import cv2
import os

# %%
cap = cv2.VideoCapture("C:\Python Programming\LIU\Data\Videos\2025-03-06_MNG-KEF\IMG_3738.mov")
# show middle frame of the video, then collect x,y coordinates of the points on mouseclick event
ret, frame = cap.read()
cv2.imshow("frame", frame)
cv2.waitKey(0)
cv2.destroyAllWindows()
# close the video

# %%
help(dlc.Capture)
# Out:
# Help on function CropVideo in module deeplabcut.utils.auxfun_videos:
#
# CropVideo(vname, width=256, height=256, origin_x=0, origin_y=0, outsuffix='cropped', outpath=None, useGUI=False)
#     Auxiliary function to crop a video and output it to the same folder with "outsuffix" appended in its name.
#     Width and height will control the new dimensions.
#
#     Returns the full path to the downsampled video!
#
#     ffmpeg -i in.mp4 -filter:v "crop=out_w:out_h:x:y" out.mp4
#
#     Parameter
#     ----------
#     vname : string
#         A string containing the full path of the video.
#
#     width: int
#         width of output video
#
#     height: int
#         height of output video.
#
#     origin_x, origin_y: int
#         x- and y- axis origin of bounding box for cropping.
#
#     outsuffix: str
#         Suffix for output videoname (see example).
#
#     outpath: str
#         Output path for saving video to (by default will be the same folder as the video)
#
#     Examples
# ...
